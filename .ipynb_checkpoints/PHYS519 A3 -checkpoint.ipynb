# %%
import random 
import matplotlib.pyplot as plt
import numpy as np

# %%
t_final = 1000
delta_t = 0.01
n = int(t_final/delta_t)
alpha_scaling = 1
alpha = alpha_scaling*delta_t
E = 5

# %%
y = np.zeros(n)
y[0] = 1

for i in range(1,n):
    y[i] = y[i-1] + alpha*E*y[i-1]*(1-y[i-1]**2) + np.sqrt(alpha/2)*random.gauss(0,1)

# %%
def normalize(y,dx):
    return y/np.sum(y*dx)

# %%
y_boltzmann = np.linspace(-1.5,1.5,100)
p_boltzmann = np.exp(-E*(1-y_boltzmann**2)**2)
dx_theory = y_boltzmann[1]-y_boltzmann[0]
p_boltzmann_normalized = normalize(p_boltzmann,dx_theory)
plt.plot(y_boltzmann,p_boltzmann_normalized)
plt.hist(y,density=True,bins=60)
plt.xlabel('y')
plt.ylabel('Probability Density')
plt.title('Probability Density Function of y for E = %.2f'%(E))
# Out:
# Text(0.5, 1.0, 'Probability Density Function of y for E = 5.00')

# %%
t = np.linspace(0,t_final,n)
plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('y')
plt.title('Trajectory of y for E = %.2f'%(E))
# Out:
# Text(0.5, 1.0, 'Trajectory of y for E = 5.00')

# %%
t_final = 1000
delta_t = 0.01
n = int(t_final/delta_t)
alpha_scaling = 1
alpha = alpha_scaling*delta_t

transitions = []
E = np.linspace(1,5,100)

for j in E:
    
    y = np.zeros(n)
    transitions_temp = 0
    
    y[0] = 1

    for i in range(1,n):
        y[i] = y[i-1] + alpha*j*y[i-1]*(1-y[i-1]**2) + np.sqrt(alpha/2)*random.gauss(0,1)
    
    for k in range(1,n):
        if (y[k] > 0 and y[k-1] < 0) or (y[k] < 0 and y[k-1] > 0):
            transitions_temp += 1
    transitions.append(transitions_temp)

# %%
current = np.array(transitions)/t_final
current
# Out:
# array([0.849, 1.152, 1.028, 1.092, 0.802, 0.932, 1.003, 0.874, 0.796,
#        0.9  , 0.694, 0.794, 0.784, 0.921, 0.806, 0.683, 0.619, 0.703,
#        0.539, 0.674, 0.637, 0.634, 0.483, 0.525, 0.532, 0.445, 0.544,
#        0.525, 0.543, 0.546, 0.547, 0.437, 0.379, 0.448, 0.445, 0.367,
#        0.477, 0.42 , 0.415, 0.247, 0.379, 0.344, 0.327, 0.272, 0.352,
#        0.36 , 0.303, 0.236, 0.279, 0.217, 0.189, 0.197, 0.279, 0.268,
#        0.285, 0.206, 0.206, 0.206, 0.147, 0.235, 0.178, 0.175, 0.17 ,
#        0.153, 0.136, 0.192, 0.134, 0.144, 0.123, 0.165, 0.113, 0.169,
#        0.149, 0.127, 0.127, 0.109, 0.085, 0.132, 0.073, 0.066, 0.1  ,
#        0.033, 0.062, 0.059, 0.085, 0.079, 0.065, 0.066, 0.039, 0.051,
#        0.073, 0.029, 0.018, 0.079, 0.021, 0.036, 0.083, 0.052, 0.041,
#        0.042])

# %%
x = np.exp(-E)
plt.plot(x,current)
plt.xlabel('$e^{-E}$')
plt.ylabel('Current (transitions/time)')
plt.title('Current vs. $e^{-E}$')
# Out:
# Text(0.5, 1.0, 'Current vs. $e^{-E}$')
