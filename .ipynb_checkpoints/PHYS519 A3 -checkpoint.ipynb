# %%
import random 
import matplotlib.pyplot as plt
import numpy as np

# %%
t_final = 1000
delta_t = 0.01
n = int(t_final/delta_t)
alpha_scaling = 1
alpha = alpha_scaling*delta_t
E = 10

# %%
y = np.zeros(n)
y[0] = 1

for i in range(1,n):
    y[i] = y[i-1] + alpha*E*y[i-1]*(1-y[i-1]**2) + np.sqrt(alpha/2)*random.gauss(0,1)

# %%
def normalize(y,dx):
    return y/np.sum(y*dx)

# %%
y_boltzmann = np.linspace(-1.5,1.5,100)
p_boltzmann = np.exp(-E*(1-y_boltzmann**2)**2)
dx_theory = y_boltzmann[1]-y_boltzmann[0]
p_boltzmann_normalized = normalize(p_boltzmann,dx_theory)
plt.plot(y_boltzmann,p_boltzmann_normalized)
plt.hist(y,density=True,bins=60)
plt.xlabel('y')
plt.ylabel('Probability Density')
plt.title('Probability Density Function of y for E = %.2f'%(E))
# Out:
# Text(0.5, 1.0, 'Probability Density Function of y for E = 10.00')

# %%
t = np.linspace(0,t_final,n)
plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('y')
plt.title('Trajectory of y for E = %.2f'%(E))
# Out:
# Text(0.5, 1.0, 'Trajectory of y for E = 10.00')

# %%
t_final = 1000
delta_t = 0.01
n = int(t_final/delta_t)
alpha_scaling = 1
alpha = alpha_scaling*delta_t

transitions = []
E = np.linspace(1,5,100)

for j in E:
    
    y = np.zeros(n)
    transitions_temp = 0
    
    y[0] = 1

    for i in range(1,n):
        y[i] = y[i-1] + alpha*j*y[i-1]*(1-y[i-1]**2) + np.sqrt(alpha/2)*random.gauss(0,1)
    
    for k in range(1,n):
        if (y[k] > 0 and y[k-1] < 0) or (y[k] < 0 and y[k-1] > 0):
            transitions_temp += 1
    transitions.append(transitions_temp)

# %%
current = np.array(transitions)/t_final
current
# Out:
# array([1.007, 1.058, 0.951, 0.705, 0.872, 0.821, 0.914, 0.936, 0.92 ,
#        0.956, 0.999, 0.87 , 0.743, 0.685, 0.85 , 0.699, 0.657, 0.671,
#        0.737, 0.671, 0.605, 0.618, 0.552, 0.621, 0.406, 0.608, 0.546,
#        0.509, 0.522, 0.369, 0.526, 0.349, 0.389, 0.353, 0.425, 0.43 ,
#        0.527, 0.334, 0.391, 0.279, 0.35 , 0.404, 0.298, 0.312, 0.279,
#        0.315, 0.215, 0.318, 0.3  , 0.28 , 0.377, 0.295, 0.223, 0.236,
#        0.207, 0.256, 0.232, 0.193, 0.16 , 0.221, 0.163, 0.124, 0.162,
#        0.13 , 0.109, 0.153, 0.157, 0.177, 0.139, 0.153, 0.139, 0.118,
#        0.092, 0.089, 0.107, 0.074, 0.12 , 0.061, 0.089, 0.066, 0.132,
#        0.091, 0.119, 0.06 , 0.106, 0.058, 0.039, 0.051, 0.06 , 0.076,
#        0.028, 0.072, 0.038, 0.056, 0.058, 0.06 , 0.076, 0.025, 0.057,
#        0.061])

# %%
x = np.exp(-E)
plt.plot(x,current)
plt.xlabel('$e^{-E}$')
plt.ylabel('Current (transitions/time)')
plt.title('Current vs. $e^{-E}$')
# Out:
# Text(0.5, 1.0, 'Current vs. $e^{-E}$')
