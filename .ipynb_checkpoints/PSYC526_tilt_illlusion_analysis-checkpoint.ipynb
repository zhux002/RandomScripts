# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pingouin as pg 

# %matplotlib inline

# %%
df = pd.read_csv('Assignment6_Data_Flat.csv')
display(df)
# Out:
#      Unnamed: 0     participant surroundCentreStr  surroundLambdaPix  \
# 0             0   Participant 1             12/12                 12
# 1             1   Participant 1             12/12                 12
# 2             2   Participant 1             48/12                 48
# 3             3   Participant 1             48/12                 48
# 4             4   Participant 1             12/48                 12
# ..          ...             ...               ...                ...
# 227         227  Participant 29             48/12                 48
# 228         228  Participant 29             12/48                 12
# 229         229  Participant 29             12/48                 12
# 230         230  Participant 29             48/48                 48
# 231         231  Participant 29             48/48                 48
#
#      centreLambdaPix  surroundOrientationDeg  \
# 0                 12                     -20
# 1                 12                      20
# 2                 12                     -20
# 3                 12                      20
# 4                 48                     -20
# ..               ...                     ...
# 227               12                      20
# 228               48                     -20
# 229               48                      20
# 230               48                     -20
# 231               48                      20
#
#      centreOverSurroundWavelengthRatio  PSEDeg  PSERelativeToSurroundDeg
# 0                                 1.00   -0.96                      0.96
# 1                                 1.00    0.78                      0.78
# 2                                 0.25    0.00                     -0.00
# 3                                 0.25    0.59                      0.59
# 4                                 4.00   -0.43                      0.43
# ..                                 ...     ...                       ...
# 227                               0.25    0.11                      0.11
# 228                               4.00   -0.66                      0.66
# 229                               4.00   -0.04                     -0.04
# 230                               1.00   -1.16                      1.16
# 231                               1.00    0.38                      0.38
#
# [232 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(font_scale = 2)

# %%
sns.boxplot(x = 'surroundOrientationDeg', 
            y = 'PSEDeg', data = df)
# Out:
# <AxesSubplot:xlabel='surroundOrientationDeg', ylabel='PSEDeg'>

# %%
sns.boxplot(x = 'surroundCentreStr',
            hue = 'surroundOrientationDeg',
            y = 'PSERelativeToSurroundDeg',
            data = df, bootstrap = 10000, notch = True)
fig.savefig('BoxPlot.png')

# %%
sns.barplot(x = 'surroundCentreStr',
            hue = 'surroundOrientationDeg',
            y = 'PSERelativeToSurroundDeg',
            data = df,
            n_boot = 1000)
# Out:
# <AxesSubplot:xlabel='surroundCentreStr', ylabel='PSERelativeToSurroundDeg'>

# %%
sns.boxplot(x = 'surroundCentreStr',
            y = 'PSERelativeToSurroundDeg',
            data = df)
# Out:
# <AxesSubplot:xlabel='surroundCentreStr', ylabel='PSERelativeToSurroundDeg'>

# %%
pg.rm_anova(dv = 'PSERelativeToSurroundDeg',
            within = ['surroundCentreStr','surroundOrientationDeg'],
            subject = 'participant', data = df)
# Out:
#                                        Source         SS  ddof1  ddof2  \
# 0                           surroundCentreStr  11.508850      3     84
# 1                      surroundOrientationDeg   2.274228      1     28
# 2  surroundCentreStr * surroundOrientationDeg   1.794956      3     84
#
#          MS          F         p-unc     p-GG-corr       np2       eps
# 0  3.836283  26.544216  3.580657e-12  4.169062e-10  0.486655  0.793375
# 1  2.274228   3.562869  6.949088e-02  6.949088e-02  0.112882  1.000000
# 2  0.598319   2.341617  7.903318e-02  1.092946e-01  0.077175  0.625478

# %%
pg.pairwise_ttests(dv = 'PSERelativeToSurroundDeg',
            within = ['surroundCentreStr','surroundOrientationDeg'],
            subject = 'participant', data = df)
# Out:
#                                       Contrast surroundCentreStr      A  \
# 0                            surroundCentreStr                 -  12/12
# 1                            surroundCentreStr                 -  12/12
# 2                            surroundCentreStr                 -  12/12
# 3                            surroundCentreStr                 -  12/48
# 4                            surroundCentreStr                 -  12/48
# 5                            surroundCentreStr                 -  48/12
# 6                       surroundOrientationDeg                 -    -20
# 7   surroundCentreStr * surroundOrientationDeg             12/12    -20
# 8   surroundCentreStr * surroundOrientationDeg             12/48    -20
# 9   surroundCentreStr * surroundOrientationDeg             48/12    -20
# 10  surroundCentreStr * surroundOrientationDeg             48/48    -20
#
#         B Paired  Parametric         T   dof alternative         p-unc  \
# 0   12/48   True        True  1.568298  28.0   two-sided  1.280449e-01
# 1   48/12   True        True  7.891870  28.0   two-sided  1.350920e-08
# 2   48/48   True        True -1.319793  28.0   two-sided  1.975936e-01
# 3   48/12   True        True  5.450356  28.0   two-sided  8.109284e-06
# 4   48/48   True        True -3.978972  28.0   two-sided  4.445668e-04
# 5   48/48   True        True -9.268157  28.0   two-sided  5.012945e-10
# 6      20   True        True  1.887556  28.0   two-sided  6.949088e-02
# 7      20   True        True  0.123328  28.0   two-sided  9.027283e-01
# 8      20   True        True  2.103970  28.0   two-sided  4.448813e-02
# 9      20   True        True  0.258236  28.0   two-sided  7.981135e-01
# 10     20   True        True  1.981183  28.0   two-sided  5.746869e-02
#
#          BF10    hedges
# 0       0.589  0.363205
# 1   9.783e+05  1.556976
# 2       0.432 -0.320773
# 3    2571.461  1.321754
# 4      68.578 -0.753389
# 5   2.172e+07 -2.179752
# 6       0.936  0.558739
# 7       0.199  0.030782
# 8        1.33  0.655247
# 9       0.204  0.079286
# 10      1.086  0.601553

# %%
pg.rm_anova(dv = 'PSERelativeToSurroundDeg',
            within = ['surroundLambdaPix','centreLambdaPix'],
            subject = 'participant', data = df)
# Out:
#                                 Source        SS  ddof1  ddof2        MS  \
# 0                    surroundLambdaPix  0.403914      1     28  0.403914
# 1                      centreLambdaPix  1.572285      1     28  1.572285
# 2  surroundLambdaPix * centreLambdaPix  3.778226      1     28  3.778226
#
#            F         p-unc     p-GG-corr       np2  eps
# 0   6.673833  1.529779e-02  1.529779e-02  0.192475  1.0
# 1  14.381413  7.313170e-04  7.313170e-04  0.339333  1.0
# 2  80.496044  9.972749e-10  9.972749e-10  0.741926  1.0

# %%
pg.pairwise_ttests(dv = 'PSERelativeToSurroundDeg',
            within = ['surroundLambdaPix','centreLambdaPix'],
            subject = 'participant', data = df)
# Out:
#                               Contrast surroundLambdaPix   A   B Paired  \
# 0                    surroundLambdaPix                 -  12  48   True
# 1                      centreLambdaPix                 -  12  48   True
# 2  surroundLambdaPix * centreLambdaPix                12  12  48   True
# 3  surroundLambdaPix * centreLambdaPix                48  12  48   True
#
#    Parametric         T   dof alternative         p-unc       BF10    hedges
# 0        True  2.583376  28.0   two-sided  1.529779e-02      3.186  0.485190
# 1        True -3.792283  28.0   two-sided  7.313170e-04     44.082 -0.869565
# 2        True  1.568298  28.0   two-sided  1.280449e-01      0.589  0.363205
# 3        True -9.268157  28.0   two-sided  5.012945e-10  2.172e+07 -2.179752
